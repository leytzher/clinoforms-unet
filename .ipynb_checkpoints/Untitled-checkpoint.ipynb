# %%
import torch
from torch.utils.data import DataLoader
import torch.nn as nn
from torch.autograd import Variable
import numpy as np
import matplotlib.pyplot as plt
from random import randint
from unet.data import SeismicData
from unet.nnet import UNet   
from unet.nnet import SoftDiceLoss, BinaryCrossEntropyLoss2d
# %matplotlib inline

# %%
# 1. Define train and test datasets

train_dataset = SeismicData(image_path='./seismic/train/images/', mask_path='./seismic/train/masks/')
test_dataset = SeismicData(image_path='./seismic/test/images/', mask_path='./seismic/test/masks/')

# 2. Initialize data loaders. The SeismicData class does data augmentation on sampling

train_data_load = DataLoader(dataset=train_dataset, batch_size=4, shuffle=True, num_workers=16)
test_data_load = DataLoader(dataset=test_dataset, batch_size=1, shuffle=True)

# 3. Initialize Neural Network 
device = torch.device("cuda:0")
print(device)

model = UNet()
model = model.to(device)

optimizer = torch.optim.RMSprop(model.parameters(), lr=0.0001)

# Save history to csv file 
header = ['epoch', 'train_loss', 'train_acc', 'val_loss', 'val_acc']
save_file_name = "./history/RMS/historyRMS.csv"
save_dir = './history/RMS'

# save images
model_save_dir = "../history/RMS/saved_models3"
image_save_path = "../history/RMS/result_images3"

# 4.  Start training

print("[INFO] Starting Training...")
epochs = 2000
# criterion = BinaryCrossEntropyLoss2d().forward()


for i in range(0,epochs):
    model.train()
    for batch, (images, masks) in enumerate(train_data_load):
        # Move input data to GPU
        images = images.float()
        images = Variable(images.cuda())
        masks = Variable(masks.cuda())
        outputs = model(images)
        loss = BinaryCrossEntropyLoss2d().forward(outputs,masks.float()) + SoftDiceLoss().forward(outputs,masks.float())
        optimizer.zero_grad()
        # backpropagation
        loss.backward()
        # update weights
        optimizer.step()
    print(f'[INFO] Epoch {i+1}, Train loss: {loss}')
# Out:
# cuda:0
# [INFO] Starting Training...
# [INFO] Epoch 1, Train loss: 1.1700820922851562
# [INFO] Epoch 2, Train loss: 1.0387043952941895
# [INFO] Epoch 3, Train loss: 1.0799223184585571
# [INFO] Epoch 4, Train loss: 1.1112009286880493
# [INFO] Epoch 5, Train loss: 1.1488267183303833
# [INFO] Epoch 6, Train loss: 1.2444989681243896
# [INFO] Epoch 7, Train loss: 1.12691330909729
# [INFO] Epoch 8, Train loss: 1.1387383937835693
# [INFO] Epoch 9, Train loss: 1.102156162261963
# [INFO] Epoch 10, Train loss: 1.1192467212677002
# [INFO] Epoch 11, Train loss: 1.1332805156707764
# [INFO] Epoch 12, Train loss: 1.0957175493240356
# [INFO] Epoch 13, Train loss: 1.1352492570877075
# [INFO] Epoch 14, Train loss: 1.089758038520813
# [INFO] Epoch 15, Train loss: 1.068403959274292
# [INFO] Epoch 16, Train loss: 1.0236473083496094
# [INFO] Epoch 17, Train loss: 1.0012390613555908
# [INFO] Epoch 18, Train loss: 0.985460638999939
# [INFO] Epoch 19, Train loss: 0.9671656489372253
# [INFO] Epoch 20, Train loss: 1.0252598524093628
# [INFO] Epoch 21, Train loss: 1.01822030544281
# [INFO] Epoch 22, Train loss: 1.0654220581054688
# [INFO] Epoch 23, Train loss: 1.0088893175125122
# [INFO] Epoch 24, Train loss: 1.0029048919677734
# [INFO] Epoch 25, Train loss: 1.015181541442871
# [INFO] Epoch 26, Train loss: 1.0245767831802368
# [INFO] Epoch 27, Train loss: 0.9980310201644897
# [INFO] Epoch 28, Train loss: 0.9412218332290649
# [INFO] Epoch 29, Train loss: 0.932494580745697
# [INFO] Epoch 30, Train loss: 1.0049718618392944
# [INFO] Epoch 31, Train loss: 0.9950847625732422
# [INFO] Epoch 32, Train loss: 0.9043198823928833
# [INFO] Epoch 33, Train loss: 1.0155463218688965
# [INFO] Epoch 34, Train loss: 0.9691982865333557
# [INFO] Epoch 35, Train loss: 0.9382990598678589
# [INFO] Epoch 36, Train loss: 0.9766203165054321
# [INFO] Epoch 37, Train loss: 0.9536066651344299
# [INFO] Epoch 38, Train loss: 0.9745783805847168
# [INFO] Epoch 39, Train loss: 0.9504920244216919
# [INFO] Epoch 40, Train loss: 0.9569276571273804
# [INFO] Epoch 41, Train loss: 1.0707695484161377
# [INFO] Epoch 42, Train loss: 1.1115689277648926
# [INFO] Epoch 43, Train loss: 1.0091774463653564
# [INFO] Epoch 44, Train loss: 1.0077059268951416
# [INFO] Epoch 45, Train loss: 0.9630894064903259
# [INFO] Epoch 46, Train loss: 0.94632887840271
# [INFO] Epoch 47, Train loss: 0.9469022154808044
# [INFO] Epoch 48, Train loss: 0.9200446009635925
# [INFO] Epoch 49, Train loss: 0.9470314979553223
# [INFO] Epoch 50, Train loss: 0.9630545973777771
# [INFO] Epoch 51, Train loss: 1.0661499500274658
# [INFO] Epoch 52, Train loss: 1.0249078273773193
# [INFO] Epoch 53, Train loss: 0.9685854315757751
# [INFO] Epoch 54, Train loss: 1.0291333198547363
# [INFO] Epoch 55, Train loss: 0.9181603193283081
# [INFO] Epoch 56, Train loss: 1.042911171913147
# [INFO] Epoch 57, Train loss: 0.9095494747161865
# [INFO] Epoch 58, Train loss: 0.9964563846588135
# [INFO] Epoch 59, Train loss: 0.9583839178085327
# [INFO] Epoch 60, Train loss: 0.9307534098625183
# [INFO] Epoch 61, Train loss: 0.9829208850860596
# [INFO] Epoch 62, Train loss: 0.9530900120735168
# [INFO] Epoch 63, Train loss: 0.9703912734985352
# [INFO] Epoch 64, Train loss: 0.9140568375587463
# [INFO] Epoch 65, Train loss: 1.0182198286056519
# [INFO] Epoch 66, Train loss: 0.9641398787498474
# [INFO] Epoch 67, Train loss: 0.9603971838951111
# [INFO] Epoch 68, Train loss: 0.9857914447784424
# [INFO] Epoch 69, Train loss: 0.9489774703979492
# [INFO] Epoch 70, Train loss: 1.0579068660736084
# [INFO] Epoch 71, Train loss: 0.8772038817405701
# [INFO] Epoch 72, Train loss: 1.009464144706726
# [INFO] Epoch 73, Train loss: 0.9179189205169678
# [INFO] Epoch 74, Train loss: 0.925467312335968
# [INFO] Epoch 75, Train loss: 0.9103055000305176
# [INFO] Epoch 76, Train loss: 1.0037009716033936
# [INFO] Epoch 77, Train loss: 0.9760496020317078
# [INFO] Epoch 78, Train loss: 0.9231804013252258
# [INFO] Epoch 79, Train loss: 0.8921318054199219
# [INFO] Epoch 80, Train loss: 0.9608950018882751
# [INFO] Epoch 81, Train loss: 0.920976996421814
# [INFO] Epoch 82, Train loss: 0.9135482907295227
# [INFO] Epoch 83, Train loss: 0.9663148522377014
# [INFO] Epoch 84, Train loss: 0.9843955039978027
# [INFO] Epoch 85, Train loss: 1.0139213800430298
# [INFO] Epoch 86, Train loss: 0.8366493582725525
# [INFO] Epoch 87, Train loss: 0.9674765467643738
# [INFO] Epoch 88, Train loss: 0.9579839110374451
# [INFO] Epoch 89, Train loss: 0.7657034397125244
# [INFO] Epoch 90, Train loss: 0.8626707792282104
# [INFO] Epoch 91, Train loss: 0.766009509563446
# [INFO] Epoch 92, Train loss: 0.8929872512817383
# [INFO] Epoch 93, Train loss: 0.8093018531799316
# [INFO] Epoch 94, Train loss: 0.6982252597808838
# [INFO] Epoch 95, Train loss: 0.7783940434455872
# [INFO] Epoch 96, Train loss: 0.7228216528892517
# [INFO] Epoch 97, Train loss: 0.8286058306694031
# [INFO] Epoch 98, Train loss: 0.8478716611862183
# [INFO] Epoch 99, Train loss: 0.7470711469650269
# [INFO] Epoch 100, Train loss: 0.6964851021766663
# [INFO] Epoch 101, Train loss: 0.8682970404624939
# [INFO] Epoch 102, Train loss: 0.8494056463241577
# [INFO] Epoch 103, Train loss: 0.8968654274940491
# [INFO] Epoch 104, Train loss: 0.6014832258224487
# [INFO] Epoch 105, Train loss: 0.8311609625816345
# [INFO] Epoch 106, Train loss: 0.9622527360916138
# [INFO] Epoch 107, Train loss: 0.7726678848266602
# [INFO] Epoch 108, Train loss: 0.5433232188224792
# [INFO] Epoch 109, Train loss: 0.6886013746261597
# [INFO] Epoch 110, Train loss: 0.5695637464523315
# [INFO] Epoch 111, Train loss: 0.7621358036994934
# [INFO] Epoch 112, Train loss: 0.5503466725349426
# [INFO] Epoch 113, Train loss: 0.7789502143859863
# [INFO] Epoch 114, Train loss: 0.621620774269104
# [INFO] Epoch 115, Train loss: 0.5511326789855957
# [INFO] Epoch 116, Train loss: 0.5040706396102905
# [INFO] Epoch 117, Train loss: 0.5707660913467407
# [INFO] Epoch 118, Train loss: 0.8083305358886719
# [INFO] Epoch 119, Train loss: 0.4231758415699005
# [INFO] Epoch 120, Train loss: 0.7083548307418823
# [INFO] Epoch 121, Train loss: 0.5007311701774597
# [INFO] Epoch 122, Train loss: 0.6669491529464722
# [INFO] Epoch 123, Train loss: 0.413628488779068
# [INFO] Epoch 124, Train loss: 0.5151627659797668
# [INFO] Epoch 125, Train loss: 0.42921143770217896
# [INFO] Epoch 126, Train loss: 0.7511547207832336
# [INFO] Epoch 127, Train loss: 0.5453563928604126
# [INFO] Epoch 128, Train loss: 0.7403919100761414
# [INFO] Epoch 129, Train loss: 0.5357206463813782
# [INFO] Epoch 130, Train loss: 0.5566890239715576
# [INFO] Epoch 131, Train loss: 0.567948579788208
# [INFO] Epoch 132, Train loss: 0.452985942363739
# [INFO] Epoch 133, Train loss: 0.5808939933776855
# [INFO] Epoch 134, Train loss: 0.41054821014404297
# [INFO] Epoch 135, Train loss: 0.36458975076675415
# [INFO] Epoch 136, Train loss: 0.49419519305229187
# [INFO] Epoch 137, Train loss: 0.4585793614387512
# [INFO] Epoch 138, Train loss: 0.7468501329421997
# [INFO] Epoch 139, Train loss: 0.4497658908367157
# [INFO] Epoch 140, Train loss: 0.6026074886322021
# [INFO] Epoch 141, Train loss: 0.34850335121154785
# [INFO] Epoch 142, Train loss: 0.4163634181022644
# [INFO] Epoch 143, Train loss: 0.42499735951423645
# [INFO] Epoch 144, Train loss: 0.3543582558631897
# [INFO] Epoch 145, Train loss: 0.2825939953327179
# [INFO] Epoch 146, Train loss: 0.40724873542785645
# [INFO] Epoch 147, Train loss: 0.40923619270324707
# [INFO] Epoch 148, Train loss: 0.4079112112522125
# [INFO] Epoch 149, Train loss: 0.6329047083854675
# [INFO] Epoch 150, Train loss: 0.19935160875320435
# [INFO] Epoch 151, Train loss: 0.7745078206062317
# [INFO] Epoch 152, Train loss: 0.23844033479690552
# [INFO] Epoch 153, Train loss: 0.29283806681632996
# [INFO] Epoch 154, Train loss: 0.3426607847213745
# [INFO] Epoch 155, Train loss: 0.3894996643066406
# [INFO] Epoch 156, Train loss: 0.340503454208374
# [INFO] Epoch 157, Train loss: 0.44506725668907166
# [INFO] Epoch 158, Train loss: 0.2863213121891022
# [INFO] Epoch 159, Train loss: 0.43162497878074646
# [INFO] Epoch 160, Train loss: 0.46215343475341797
# [INFO] Epoch 161, Train loss: 0.2810448408126831
# [INFO] Epoch 162, Train loss: 0.3860747516155243
# [INFO] Epoch 163, Train loss: 0.3885427713394165
# [INFO] Epoch 164, Train loss: 0.3074800968170166
# [INFO] Epoch 165, Train loss: 0.2835281491279602
# [INFO] Epoch 166, Train loss: 0.3775302767753601
# [INFO] Epoch 167, Train loss: 0.22178906202316284
# [INFO] Epoch 168, Train loss: 0.19125738739967346
# [INFO] Epoch 169, Train loss: 0.26714855432510376
# [INFO] Epoch 170, Train loss: 0.30431169271469116
# [INFO] Epoch 171, Train loss: 0.46066880226135254
# [INFO] Epoch 172, Train loss: 0.21342536807060242
# [INFO] Epoch 173, Train loss: 0.40028589963912964
# [INFO] Epoch 174, Train loss: 0.29945653676986694
# [INFO] Epoch 175, Train loss: 0.4245935082435608
# [INFO] Epoch 176, Train loss: 0.45927003026008606
# [INFO] Epoch 177, Train loss: 0.21759162843227386
# [INFO] Epoch 178, Train loss: 0.2800881266593933
# [INFO] Epoch 179, Train loss: 0.1967717409133911
# [INFO] Epoch 180, Train loss: 0.3974379897117615
# [INFO] Epoch 181, Train loss: 0.5065367221832275
# [INFO] Epoch 182, Train loss: 0.49745652079582214
# [INFO] Epoch 183, Train loss: 0.16958896815776825
# [INFO] Epoch 184, Train loss: 0.35450315475463867
# [INFO] Epoch 185, Train loss: 0.3197990655899048
# [INFO] Epoch 186, Train loss: 0.19649069011211395
# [INFO] Epoch 187, Train loss: 0.3187166750431061
# [INFO] Epoch 188, Train loss: 0.17755690217018127
# [INFO] Epoch 189, Train loss: 0.1625770628452301
# [INFO] Epoch 190, Train loss: 0.3086426556110382
# [INFO] Epoch 191, Train loss: 0.39634284377098083
# [INFO] Epoch 192, Train loss: 0.5293117165565491
# [INFO] Epoch 193, Train loss: 0.2358444184064865
# [INFO] Epoch 194, Train loss: 0.3109743893146515
# [INFO] Epoch 195, Train loss: 0.39108073711395264
# [INFO] Epoch 196, Train loss: 0.3461487293243408
# [INFO] Epoch 197, Train loss: 0.17460668087005615
# [INFO] Epoch 198, Train loss: 0.5629507303237915
# [INFO] Epoch 199, Train loss: 0.3192997872829437
# [INFO] Epoch 200, Train loss: 0.3117850422859192
# [INFO] Epoch 201, Train loss: 0.24101999402046204
# [INFO] Epoch 202, Train loss: 0.30925360321998596
# [INFO] Epoch 203, Train loss: 0.21771389245986938
# [INFO] Epoch 204, Train loss: 0.2659323513507843
# [INFO] Epoch 205, Train loss: 0.19240158796310425
# [INFO] Epoch 206, Train loss: 0.11255007982254028
# [INFO] Epoch 207, Train loss: 0.3572388291358948
# [INFO] Epoch 208, Train loss: 0.18914484977722168
# [INFO] Epoch 209, Train loss: 0.17517134547233582
# [INFO] Epoch 210, Train loss: 0.16419047117233276
# [INFO] Epoch 211, Train loss: 0.22814540565013885
# [INFO] Epoch 212, Train loss: 0.341889351606369
# [INFO] Epoch 213, Train loss: 0.24051450192928314
# [INFO] Epoch 214, Train loss: 0.1019299179315567
# [INFO] Epoch 215, Train loss: 0.490966796875
# [INFO] Epoch 216, Train loss: 0.2966838479042053
# [INFO] Epoch 217, Train loss: 0.17680573463439941
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/leytzher/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/queues.py", line 240, in _feed
#     send_bytes(obj)
#   File "/home/leytzher/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/home/leytzher/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/home/leytzher/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
# BrokenPipeError: [Errno 32] Broken pipe
#   File "/home/leytzher/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/queues.py", line 240, in _feed
#     send_bytes(obj)
#   File "/home/leytzher/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
# Traceback (most recent call last):
#   File "/home/leytzher/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/queues.py", line 240, in _feed
#     send_bytes(obj)
#   File "/home/leytzher/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/home/leytzher/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/home/leytzher/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
# BrokenPipeError: [Errno 32] Broken pipe
#   File "/home/leytzher/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/home/leytzher/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
# BrokenPipeError: [Errno 32] Broken pipe
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/leytzher/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/queues.py", line 240, in _feed
#     send_bytes(obj)
#   File "/home/leytzher/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/home/leytzher/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/home/leytzher/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
# BrokenPipeError: [Errno 32] Broken pipe
# Traceback (most recent call last):
#   File "/home/leytzher/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/queues.py", line 240, in _feed
#     send_bytes(obj)
#   File "/home/leytzher/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/home/leytzher/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/home/leytzher/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
# BrokenPipeError: [Errno 32] Broken pipe
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/leytzher/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/queues.py", line 240, in _feed
#     send_bytes(obj)
#   File "/home/leytzher/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/home/leytzher/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/home/leytzher/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
# BrokenPipeError: [Errno 32] Broken pipe
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/leytzher/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/queues.py", line 240, in _feed
#     send_bytes(obj)
#   File "/home/leytzher/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/home/leytzher/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/home/leytzher/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
# BrokenPipeError: [Errno 32] Broken pipe
# Traceback (most recent call last):
#   File "/home/leytzher/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/queues.py", line 240, in _feed
#     send_bytes(obj)
#   File "/home/leytzher/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/home/leytzher/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/home/leytzher/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
# BrokenPipeError: [Errno 32] Broken pipe
#   File "/home/leytzher/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/queues.py", line 240, in _feed
#     send_bytes(obj)
#   File "/home/leytzher/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/queues.py", line 240, in _feed
#     send_bytes(obj)
# Traceback (most recent call last):
#   File "/home/leytzher/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/queues.py", line 240, in _feed
#     send_bytes(obj)
#   File "/home/leytzher/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
# Traceback (most recent call last):
#   File "/home/leytzher/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/queues.py", line 240, in _feed
#     send_bytes(obj)
#   File "/home/leytzher/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/home/leytzher/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/home/leytzher/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
# BrokenPipeError: [Errno 32] Broken pipe
#   File "/home/leytzher/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/queues.py", line 240, in _feed
#     send_bytes(obj)
#   File "/home/leytzher/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/home/leytzher/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/home/leytzher/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
# BrokenPipeError: [Errno 32] Broken pipe
# Traceback (most recent call last):
#   File "/home/leytzher/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/queues.py", line 240, in _feed
#     send_bytes(obj)
#   File "/home/leytzher/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/home/leytzher/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/home/leytzher/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
# BrokenPipeError: [Errno 32] Broken pipe
#   File "/home/leytzher/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/home/leytzher/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/home/leytzher/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
# BrokenPipeError: [Errno 32] Broken pipe
#   File "/home/leytzher/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/home/leytzher/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
# BrokenPipeError: [Errno 32] Broken pipe
#   File "/home/leytzher/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/home/leytzher/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/home/leytzher/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
# BrokenPipeError: [Errno 32] Broken pipe
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/leytzher/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/queues.py", line 240, in _feed
#     send_bytes(obj)
#   File "/home/leytzher/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/home/leytzher/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/home/leytzher/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
# BrokenPipeError: [Errno 32] Broken pipe
#   File "/home/leytzher/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/queues.py", line 240, in _feed
#     send_bytes(obj)
#   File "/home/leytzher/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/home/leytzher/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/home/leytzher/anaconda3/envs/pytorch/lib/python3.6/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
# BrokenPipeError: [Errno 32] Broken pipe
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-6297b0a9952f> in <module>
#      41         # Move input data to GPU
#      42         images = images.float()
# ---> 43         images = Variable(images.cuda())
#      44         masks = Variable(masks.cuda())
#      45         outputs = model(images)
#
# KeyboardInterrupt:

# %%
o = outputs

# %%
m = masks

# %%
m.shape, o.shape

# %%
images

# %%
plt.imshow(images[0,0,:,:].cpu())

# %%
plt.imshow(masks[0,0,:,:].cpu())

# %%
plt.imshow(outputs[0,0,:,:].cpu().detach().numpy())

# %%
t = o.flatten()
t

# %%
m.flatten()

# %%
x = t.reshape(2,1,256,-1)

# %%
x

# %%
criterion = nn.BCELoss()
loss = criterion(t,m.float())
loss

# %%
t.size(0)

# %%
o.shape

# %%
outputs.size(0)

# %%
m2 = outputs.view(2,-1)

# %%
m2

# %%
m1 = masks.view(2,-1)

# %%
m1

# %%
m1.float().cuda()*m2
